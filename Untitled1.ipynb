# %%
from weather import *

# %%
html = get_html_from_web()                                                                                                                                                                                                           
table = get_data_from_html(html)                                                                                                                                                                                                     
df_empty = build_dataframe(table)
df_populated = populate_dataframe(df_empty, table)
df_final = clean

# %%
df = populate_dataframe(df, table)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-87a99a1d19be> in <module>()
# ----> 1 df = populate_dataframe(df, table)
#
# ~/Dropbox (MIT)/Linux/simple_scripts/weather.py in populate_dataframe(df, tag)
#     113         if row.a:
#     114             column_maker = 0
# --> 115             columns = row.find_all('td')
#     116             for column in columns:
#     117                 df.iloc[row_maker, column_maker] = column.get_text().strip()
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    1658         if ((not self.name)
#    1659             or call_function_with_tag_data
# -> 1660             or (markup and self._matches(markup, self.name))
#    1661             or (not markup and self._matches(markup_name, self.name))):
#    1662             if call_function_with_tag_data:
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _matches(self, markup, match_against, already_tried)
#    1734
#    1735         if isinstance(match_against, collections.Callable):
# -> 1736             return match_against(markup)
#    1737
#    1738         # Custom callables take the tag as an argument, but all
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in __call__(self, *args, **kwargs)
#    1039         find_all() method. Eg. tag('a') returns a list of all the A tags
#    1040         found within this tag."""
# -> 1041         return self.find_all(*args, **kwargs)
#    1042
#    1043     def __getattr__(self, tag):
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    1658         if ((not self.name)
#    1659             or call_function_with_tag_data
# -> 1660             or (markup and self._matches(markup, self.name))
#    1661             or (not markup and self._matches(markup_name, self.name))):
#    1662             if call_function_with_tag_data:
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _matches(self, markup, match_against, already_tried)
#    1734
#    1735         if isinstance(match_against, collections.Callable):
# -> 1736             return match_against(markup)
#    1737
#    1738         # Custom callables take the tag as an argument, but all
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in __call__(self, *args, **kwargs)
#    1039         find_all() method. Eg. tag('a') returns a list of all the A tags
#    1040         found within this tag."""
# -> 1041         return self.find_all(*args, **kwargs)
#    1042
#    1043     def __getattr__(self, tag):
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    1658         if ((not self.name)
#    1659             or call_function_with_tag_data
# -> 1660             or (markup and self._matches(markup, self.name))
#    1661             or (not markup and self._matches(markup_name, self.name))):
#    1662             if call_function_with_tag_data:
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _matches(self, markup, match_against, already_tried)
#    1734
#    1735         if isinstance(match_against, collections.Callable):
# -> 1736             return match_against(markup)
#    1737
#    1738         # Custom callables take the tag as an argument, but all
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in __call__(self, *args, **kwargs)
#    1039         find_all() method. Eg. tag('a') returns a list of all the A tags
#    1040         found within this tag."""
# -> 1041         return self.find_all(*args, **kwargs)
#    1042
#    1043     def __getattr__(self, tag):
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     550         while True:
#     551             try:
# --> 552                 i = next(generator)
#     553             except StopIteration:
#     554                 break
#
# ~/Environments/auto_scripts_ENV/lib/python3.5/site-packages/bs4/element.py in descendants(self)
#    1327         stopNode = self._last_descendant().next_element
#    1328         current = self.contents[0]
# -> 1329         while current is not stopNode:
#    1330             yield current
#    1331             current = current.next_element
#
# KeyboardInterrupt:

# %%
print(range(3))
# Out:
# range(0, 3)

# %%
for n in range(0, 3):
    print(n)
# Out:
# 0
# 1
# 2
